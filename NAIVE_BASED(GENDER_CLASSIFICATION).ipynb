# %%
import numpy as np
import pandas as pd

# %%
data = pd.read_csv('/content/gender_classification_v7.csv')

# %%
data.head()
# Out:
#    long_hair  forehead_width_cm  forehead_height_cm  nose_wide  nose_long  \
# 0          1               11.8                 6.1          1          0
# 1          0               14.0                 5.4          0          0
# 2          0               11.8                 6.3          1          1
# 3          0               14.4                 6.1          0          1
# 4          1               13.5                 5.9          0          0
#
#    lips_thin  distance_nose_to_lip_long  gender
# 0          1                          1    Male
# 1          1                          0  Female
# 2          1                          1    Male
# 3          1                          1    Male
# 4          0                          0  Female

# %%
data.tail()
# Out:
#       long_hair  forehead_width_cm  forehead_height_cm  nose_wide  nose_long  \
# 4996          1               13.6                 5.1          0          0
# 4997          1               11.9                 5.4          0          0
# 4998          1               12.9                 5.7          0          0
# 4999          1               13.2                 6.2          0          0
# 5000          1               15.4                 5.4          1          1
#
#       lips_thin  distance_nose_to_lip_long  gender
# 4996          0                          0  Female
# 4997          0                          0  Female
# 4998          0                          0  Female
# 4999          0                          0  Female
# 5000          1                          1    Male

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5001 entries, 0 to 5000
# Data columns (total 8 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   long_hair                  5001 non-null   int64
#  1   forehead_width_cm          5001 non-null   float64
#  2   forehead_height_cm         5001 non-null   float64
#  3   nose_wide                  5001 non-null   int64
#  4   nose_long                  5001 non-null   int64
#  5   lips_thin                  5001 non-null   int64
#  6   distance_nose_to_lip_long  5001 non-null   int64
#  7   gender                     5001 non-null   object
# dtypes: float64(2), int64(5), object(1)
# memory usage: 312.7+ KB

# %%
data.describe()
# Out:
#          long_hair  forehead_width_cm  forehead_height_cm    nose_wide  \
# count  5001.000000        5001.000000         5001.000000  5001.000000
# mean      0.869626          13.181484            5.946311     0.493901
# std       0.336748           1.107128            0.541268     0.500013
# min       0.000000          11.400000            5.100000     0.000000
# 25%       1.000000          12.200000            5.500000     0.000000
# 50%       1.000000          13.100000            5.900000     0.000000
# 75%       1.000000          14.000000            6.400000     1.000000
# max       1.000000          15.500000            7.100000     1.000000
#
#          nose_long    lips_thin  distance_nose_to_lip_long
# count  5001.000000  5001.000000                5001.000000
# mean      0.507898     0.493101                   0.498900
# std       0.499988     0.500002                   0.500049
# min       0.000000     0.000000                   0.000000
# ...

# %%
(data.describe().T)
# Out:
#                             count       mean       std   min   25%   50%  \
# long_hair                  5001.0   0.869626  0.336748   0.0   1.0   1.0
# forehead_width_cm          5001.0  13.181484  1.107128  11.4  12.2  13.1
# forehead_height_cm         5001.0   5.946311  0.541268   5.1   5.5   5.9
# nose_wide                  5001.0   0.493901  0.500013   0.0   0.0   0.0
# nose_long                  5001.0   0.507898  0.499988   0.0   0.0   1.0
# lips_thin                  5001.0   0.493101  0.500002   0.0   0.0   0.0
# distance_nose_to_lip_long  5001.0   0.498900  0.500049   0.0   0.0   0.0
#
#                             75%   max
# long_hair                   1.0   1.0
# forehead_width_cm          14.0  15.5
# forehead_height_cm          6.4   7.1
# nose_wide                   1.0   1.0
# nose_long                   1.0   1.0
# lips_thin                   1.0   1.0
# distance_nose_to_lip_long   1.0   1.0

# %%
data.shape
# Out:
# (5001, 8)

# %%
import matplotlib.pyplot as plt

# %%
y = data['gender']
plt.plot(y)
plt.ylabel('gender')
# Out:
# Text(0, 0.5, 'gender')

# %%
x = data['gender']
y = data['long_hair']
plt.bar(x,y)
plt.xlabel('gender')
plt.ylabel('long_hair')
# Out:
# Text(0, 0.5, 'long_hair')

# %%
x = data['forehead_width_cm']
y = data['forehead_height_cm']
plt.scatter(x,y)
plt.xlabel('forehead_width_cm')
plt.ylabel('forehead_height_cm')
# Out:
# Text(0, 0.5, 'forehead_height_cm')

# %%
plt.pie(x=data['distance_nose_to_lip_long'])
plt.xlabel('distance_nose_to_lip_long')
# Out:
# Text(0.5, 0, 'distance_nose_to_lip_long')

# %%
plt.hist(x=data['long_hair'])
plt.xlabel('long_hair')
# Out:
# Text(0.5, 0, 'long_hair')

# %%
import seaborn as sns

# %%
sns.lineplot(x=data['gender'],y=data['long_hair'])
# Out:
# <Axes: xlabel='gender', ylabel='long_hair'>

# %%
sns.countplot(x=data['gender'])
# Out:
# <Axes: xlabel='gender', ylabel='count'>

# %%
sns.barplot(x=data['nose_long'],y=data['nose_wide'])
# Out:
# <Axes: xlabel='nose_long', ylabel='nose_wide'>

# %%
sns.scatterplot(x=data['lips_thin'],y=data['distance_nose_to_lip_long'])
# Out:
# <Axes: xlabel='lips_thin', ylabel='distance_nose_to_lip_long'>

# %%
sns.pairplot(data,hue='gender')

# %%
sns.boxplot(x=data['forehead_height_cm'])
# Out:
# <Axes: xlabel='forehead_height_cm'>

# %%
sns.distplot(x=data['forehead_width_cm'])
# Out:
# <ipython-input-29-217ddab8cd43>:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(x=data['forehead_width_cm'])
# <Axes: ylabel='Density'>

# %%
x = data.drop('gender',axis=1)
print(x)
# Out:
#       long_hair  forehead_width_cm  forehead_height_cm  nose_wide  nose_long  \
# 0             1               11.8                 6.1          1          0
# 1             0               14.0                 5.4          0          0
# 2             0               11.8                 6.3          1          1
# 3             0               14.4                 6.1          0          1
# 4             1               13.5                 5.9          0          0
# ...         ...                ...                 ...        ...        ...
# 4996          1               13.6                 5.1          0          0
# 4997          1               11.9                 5.4          0          0
# 4998          1               12.9                 5.7          0          0
# 4999          1               13.2                 6.2          0          0
# 5000          1               15.4                 5.4          1          1
#
#       lips_thin  distance_nose_to_lip_long
# ...

# %%
y = data['gender']
print(y)
# Out:
# 0         Male
# 1       Female
# 2         Male
# 3         Male
# 4       Female
#          ...
# 4996    Female
# 4997    Female
# 4998    Female
# 4999    Female
# 5000      Male
# Name: gender, Length: 5001, dtype: object

# %%
from sklearn.model_selection import train_test_split

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.30,random_state=0)

# %%
from sklearn.naive_bayes import GaussianNB

# %%
GNB = GaussianNB()

# %%
GNB.fit(x_train,y_train)
# Out:
# GaussianNB()

# %%
y_predict1 = GNB.predict(x_test)

# %%
from sklearn.metrics import accuracy_score

# %%
ALGORITHM1 = accuracy_score(y_predict1,y_test)
print(ALGORITHM1)
# Out:
# 0.9706862091938707

# %%
from sklearn.metrics import confusion_matrix

# %%
confusion_matrix(y_predict1,y_test)
# Out:
# array([[746,  26],
#        [ 18, 711]])

# %%
from sklearn.naive_bayes import MultinomialNB

# %%
MNB = MultinomialNB()

# %%
MNB.fit(x_train,y_train)
# Out:
# MultinomialNB()

# %%
y_predict2 = clf.predict(x_test)

# %%
ALGORITHM2=accuracy_score(y_predict2,y_test)
print(ALGORITHM2)
# Out:
# 0.9600266489007329

# %%
confusion_matrix(y_predict2,y_test)
# Out:
# array([[709,   5],
#        [ 55, 732]])

# %%
from sklearn.naive_bayes import BernoulliNB

# %%
BNB = BernoulliNB()

# %%
BNB.fit(x_train,y_train)
# Out:
# BernoulliNB()

# %%
y_predict3 = BNB.predict(x_test)

# %%
ALGORITHM3=accuracy_score(y_predict3,y_test)
print(ALGORITHM3)
# Out:
# 0.9580279813457695

# %%
confusion_matrix(y_predict3,y_test)
# Out:
# array([[718,  17],
#        [ 46, 720]])

# %%
from sklearn.naive_bayes import ComplementNB

# %%
CNB = ComplementNB()

# %%
CNB.fit(x_train,y_train)
# Out:
# ComplementNB()

# %%
y_predict4 = CNB.predict(x_test)

# %%
ALGORITHM4=accuracy_score(y_predict4,y_test)
print(ALGORITHM4)
# Out:
# 0.9600266489007329

# %%
confusion_matrix(y_predict4,y_test)
# Out:
# array([[709,   5],
#        [ 55, 732]])

# %%
print("GauusianNB accuracy_score is",ALGORITHM1)
print("MultinomialNB accuracy_score is",ALGORITHM2)
print("BernoulliNB accuracy_score is",ALGORITHM3)
print("COMplementNB accuracy_score is",ALGORITHM4)
# Out:
# GauusianNB accuracy_score is 0.9706862091938707
# MultinomialNB accuracy_score is 0.9600266489007329
# BernoulliNB accuracy_score is 0.9580279813457695
# COMplementNB accuracy_score is 0.9600266489007329

# %%
print("GauusianNB accuracy_score is = ",ALGORITHM1,"\n","MultinomialNB accuracy_score is = ",ALGORITHM2,"\n","BernoulliNB accuracy_score is = ",ALGORITHM3,"\n","COMplementNB accuracy_score is = ",ALGORITHM4)
# Out:
# GauusianNB accuracy_score is =  0.9706862091938707
#  MultinomialNB accuracy_score is =  0.9600266489007329
#  BernoulliNB accuracy_score is =  0.9580279813457695
#  COMplementNB accuracy_score is =  0.9600266489007329
